# %% [markdown]
# **Author:** Demetria Murphy
#
# # Research Questions:
# * *What was the Black urban ecology of safety in post-WWII Los Angeles?*
#
# * *What was the impact of shifts in neighborhood socioeconomic demographics on this ecology of safety?*
#
# # Data Sources:
# * [Green Book locations by type for SoCal, 1947](https://github.com/NYPL-publicdomain/greenbook-map/tree/master/data) (Schomburg Center for Research in Black Culture at the New York Public Library)
# * [Green Book locations by type for SoCal, 1956](https://github.com/NYPL-publicdomain/greenbook-map/tree/master/data) (Schomburg Center for Research in Black Culture at the New York Public Library)
# * [Los Angeles County Union Census Tract Data Series, 1940-1990](https://drive.google.com/drive/folders/1KiflC3DOQJoo_DTiZGzbr3-_QhvTh1nl?usp=sharing) from Ethington, Kooistra, and DeYoung
#     * From this dataset, I am interested in the following variables and years that will help me better understand the **racial demographics** of the area in 1940 and 1960 (where yy = year):
#         * **PyyB:** Population Black non-White
#             * **PyyT** used to calculate percentage of Black non-white population.
#         *  **PyyW:** Population White
#     * Median household income data is not available until 1970 in this dataset, so I will explore  a few of the following variables to better understand the surrounding **socioeconomic context** in both 1940 and 1960 (where yy = year)::
#         * **EyyH:**	Education completed high school
#         * **EyyC:**	Education completed college
#         * **OyyWC:**	Occupation White Collar
#         * **OyyBC:**	Occupation Blue Collar
#         * **HyyMVL:**	Median value of dwelling/housing units
#         * **HyyMRN:**	Housing Median Rent of Unit
# # Methodology
# 1. Import census tract data for race, GB1947, and GB1956.
# 1. Trim census tract data to 1940, 1950, and 1960.
# 1. Calculate % of education level, collar work for 1940, 1950, and 1960.
# 1. Trim or bound GB1947 and GB1956 to Los Angeles locations.
# 1. Create multi-layered subplots for GB1947 and 1940 census.
# 1. Create a function and loop through all econ categories.
# 1. Repeat for GB1956 and 1960 census.
#
# # Resulting Visualizations
# * Green Book Locations from 1947 x Economic indicator (ex. Collar Work, Education Level, Home Value/Rent)
#
# * Green Book Locations from 1956 x Economic indicator (ex. Collar Work, Education Level, Home Value/Rent) (How did location types shift?)

# %% [markdown]
# # 1. Import census tract data for race, GB1947, and GB1956.

# %%
import pandas as pd

# for spatial data
import geopandas as gpd

# for plotting
import matplotlib.pyplot as plt

# for basemaps
import contextily as ctx

import plotly.express as px

import json

# %%
filename = "Data/1947-Copy1.geojson"
file = open(filename)
gb47 = gpd.read_file(file)

# %%
gb47.head()
# Out:
#                name             address  \
# 0        around 20,  000 miles per year
# 1        St. Thomas     127 W. 10th St.
# 2  Mrs. Ed. Andrews       69 Cotton St.
# 3            Dunbar     323 N. 17th St.
# 4         Palm Leaf    328 1/2 18th St.
#
#                                          image_url image_id  \
# 0  http://images.nypl.org/index.php?id=5207629&t=q  5207629
# 1  http://images.nypl.org/index.php?id=5207645&t=q  5207645
# 2  http://images.nypl.org/index.php?id=5207645&t=q  5207645
# 3  http://images.nypl.org/index.php?id=5207645&t=q  5207645
# 4  http://images.nypl.org/index.php?id=5207645&t=q  5207645
#
#                            capture_uuid  \
# 0  2a4111a0-892b-0132-5d0d-58d385a7bbd0
# 1  2b93aef0-892b-0132-d7c7-58d385a7bbd0
# 2  2b93aef0-892b-0132-d7c7-58d385a7bbd0
# 3  2b93aef0-892b-0132-d7c7-58d385a7bbd0
# 4  2b93aef0-892b-0132-d7c7-58d385a7bbd0
#
#                                               dc_url  page  year         city  \
# 0  http://digitalcollections.nypl.org/items/2a411...    12  1947  WESTCHESTER
# 1  http://digitalcollections.nypl.org/items/2b93a...    28  1947  WESTCHESTER
# 2  http://digitalcollections.nypl.org/items/2b93a...    28  1947    ANDALUSIA
# 3  http://digitalcollections.nypl.org/items/2b93a...    28  1947   BIRMINGHAM
# 4  http://digitalcollections.nypl.org/items/2b93a...    28  1947   BIRMINGHAM
#
#        state      category                                       image_region  \
# 0  TENNESSEE  Tourist Home  {'x': 0.10086027884900624, 'y': 0.521487419283...
# 1  TENNESSEE  Tourist Home  {'x': 0.12726176115802174, 'y': 0.166629736317...
# 2  TENNESSEE  Tourist Home  {'x': 0.12907117008443908, 'y': 0.222690006647...
# 3  TENNESSEE  Tourist Home  {'x': 0.11459589867310013, 'y': 0.266341679592...
# 4  TENNESSEE  Tourist Home  {'x': 0.11670687575392039, 'y': 0.289829381785...
#
#                                     geocoded_address  geocoded_confidence  \
# 0  000 Miles Rd, Mulberry, Tennessee 37359, Unite...             0.509286
# 1  127 W 10th St, Chattanooga, Tennessee 37402, U...             0.852143
# 2  69 S Cotton St, Andalusia, Alabama 36420, Unit...             0.728333
# 3  323 N 17th St, Knoxville, Tennessee 37921, Uni...             0.852143
# 4  328 18th St, Knoxville, Tennessee 37916, Unite...             0.828333
#
#                      geometry
# 0  POINT (-86.39971 35.19817)
# 1  POINT (-85.31081 35.04481)
# 2  POINT (-86.48221 31.30161)
# 3  POINT (-83.93629 35.96380)
# 4  POINT (-83.93586 35.95957)

# %%
gb56b = gpd.read_file('Data/gb1956.csv')

# %%
gb56b
# Out:
#                                    name  \
# 0     Mrs. Sallie Galloway Tourist Home
# 1                    Ess-Tee Restaurant
# 2            C. F. Holland Tourist Home
# 3                           James Hotel
# 4             Mrs. Gladsen Tourist Home
# ...                                 ...
# 1500                            Holiday
# 1501                    Mrs. M. Jemmott
# 1502                         Casa Villa
# 1503                     Au Repos Rooms
# 1504                        Grant House
#
#                                                 address         city state  \
# 0                                     420 Butler Street     Anderson    SC
# 1                                112 East Church Street     Anderson    SC
# 2                                  1118 Richland Avenue        Aiken    SC
# 3                                     238 Spring Street   Charleston    SC
# 4                                      15 Nassau Street   Charleston    SC
# ...                                                 ...          ...   ...
# 1500  300 Sherbrooke Street West [now Rue Sherbrooke...     Montreal   [QC
# 1501                 3840 Limton Avenue [Avenue Linton]     Montreal   [QC
# 1502  258 Sherbrooke Street West [now Rue Sherbrooke...     Montreal   [QC
# 1503  1824 Dorchester [Boulevard] [now Boulevard Ren...     Montreal   [QC
# 1504  1432 Saint Antoine Street [now Rue Saint-Antoi...     Montreal   [QC
#
#         zip       category  year      oldlat        LAT       oldlong  \
# 0     29624   Tourist Home  1956  [34.496227  34.496227   -82.642532]
# 1     29624     Restaurant  1956  [34.502308  34.502308   -82.648781]
# 2     29801   Tourist Home  1956  [33.565643  33.565643   -81.734093]
# 3     29403          Hotel  1956  [32.786724  32.786724   -79.954742]
# 4     29403   Tourist Home  1956  [32.792221  32.792221   -79.937187]
# ...     ...            ...   ...         ...        ...           ...
# 1500    H2X  Not Specified  1956  [45.508682  45.508682   -73.571114]
# 1501    H3S  Not Specified  1956  [45.499153  45.499153   -73.631905]
# 1502    H2X          Villa  1956   [45.50898   45.50898   -73.570961]
# 1503    H3H          Rooms  1956  [45.492237  45.492237   -73.576408]
# 1504    H3C  Not Specified  1956  [45.493191  45.493191   -73.571396]
#
#              LONG geometry
# 0      -82.642532     None
# 1      -82.648781     None
# 2      -81.734093     None
# 3      -79.954742     None
# 4      -79.937187     None
# ...           ...      ...
# 1500   -73.571114     None
# 1501   -73.631905     None
# 1502   -73.570961     None
# 1503   -73.576408     None
# 1504   -73.571396     None
#
# [1505 rows x 12 columns]

# %%
#We don't need the oldlat and oldlong columns, so let's drop them.
columns_to_drop = ['oldlat','oldlong']
gb56b = gb56b.drop(columns_to_drop,axis=1)
gb56b.head()
# Out:
#                                 name                 address         city  \
# 0  Mrs. Sallie Galloway Tourist Home       420 Butler Street     Anderson
# 1                 Ess-Tee Restaurant  112 East Church Street     Anderson
# 2         C. F. Holland Tourist Home    1118 Richland Avenue        Aiken
# 3                        James Hotel       238 Spring Street   Charleston
# 4          Mrs. Gladsen Tourist Home        15 Nassau Street   Charleston
#
#   state    zip      category  year        LAT         LONG geometry
# 0    SC  29624  Tourist Home  1956  34.496227   -82.642532     None
# 1    SC  29624    Restaurant  1956  34.502308   -82.648781     None
# 2    SC  29801  Tourist Home  1956  33.565643   -81.734093     None
# 3    SC  29403         Hotel  1956  32.786724   -79.954742     None
# 4    SC  29403  Tourist Home  1956  32.792221   -79.937187     None

# %%
# convert df to gdf
# since data is in lat/lon's assign the crs to WGS84 (epsg:4326)
gb1956 = gpd.GeoDataFrame(gb56b, 
                       crs='epsg:4326',
                       geometry=gpd.points_from_xy(gb56b.LONG, gb56b.LAT)) #define which column is long and lat

# %%
gb1956
# Out:
#                                    name  \
# 0     Mrs. Sallie Galloway Tourist Home
# 1                    Ess-Tee Restaurant
# 2            C. F. Holland Tourist Home
# 3                           James Hotel
# 4             Mrs. Gladsen Tourist Home
# ...                                 ...
# 1500                            Holiday
# 1501                    Mrs. M. Jemmott
# 1502                         Casa Villa
# 1503                     Au Repos Rooms
# 1504                        Grant House
#
#                                                 address         city state  \
# 0                                     420 Butler Street     Anderson    SC
# 1                                112 East Church Street     Anderson    SC
# 2                                  1118 Richland Avenue        Aiken    SC
# 3                                     238 Spring Street   Charleston    SC
# 4                                      15 Nassau Street   Charleston    SC
# ...                                                 ...          ...   ...
# 1500  300 Sherbrooke Street West [now Rue Sherbrooke...     Montreal   [QC
# 1501                 3840 Limton Avenue [Avenue Linton]     Montreal   [QC
# 1502  258 Sherbrooke Street West [now Rue Sherbrooke...     Montreal   [QC
# 1503  1824 Dorchester [Boulevard] [now Boulevard Ren...     Montreal   [QC
# 1504  1432 Saint Antoine Street [now Rue Saint-Antoi...     Montreal   [QC
#
#         zip       category  year        LAT         LONG  \
# 0     29624   Tourist Home  1956  34.496227   -82.642532
# 1     29624     Restaurant  1956  34.502308   -82.648781
# 2     29801   Tourist Home  1956  33.565643   -81.734093
# 3     29403          Hotel  1956  32.786724   -79.954742
# 4     29403   Tourist Home  1956  32.792221   -79.937187
# ...     ...            ...   ...        ...          ...
# 1500    H2X  Not Specified  1956  45.508682   -73.571114
# 1501    H3S  Not Specified  1956  45.499153   -73.631905
# 1502    H2X          Villa  1956   45.50898   -73.570961
# 1503    H3H          Rooms  1956  45.492237   -73.576408
# 1504    H3C  Not Specified  1956  45.493191   -73.571396
#
#                         geometry
# 0     POINT (-82.64253 34.49623)
# 1     POINT (-82.64878 34.50231)
# 2     POINT (-81.73409 33.56564)
# 3     POINT (-79.95474 32.78672)
# 4     POINT (-79.93719 32.79222)
# ...                          ...
# 1500  POINT (-73.57111 45.50868)
# 1501  POINT (-73.63191 45.49915)
# 1502  POINT (-73.57096 45.50898)
# 1503  POINT (-73.57641 45.49224)
# 1504  POINT (-73.57140 45.49319)
#
# [1505 rows x 10 columns]

# %%
gdf = gpd.read_file('Data/LA4090V101.SHP')

# %%
gdf.head()
# Out:
#            AREA     PERIMETER   CTBNA  P40T  P40WNH  P40BNH  P40ONH  P40HIS  \
# 0  5.110526e+08   97788.60030  900100   615     605       1       3       6
# 1  4.139640e+08  112335.98215  900200  1312    1287       2      11      12
# 2  9.627060e+08  143092.75454  901202  1063    1038       1      20       4
# 3  2.129940e+08   60542.54667  900900  1150    1122       3      14      10
# 4  5.892047e+07   38184.45935  900300   522     511       2       5       5
#
#    P40TW  P40NATW  ...   O90BC  R90SH85  R90SC85  R90OT85  H90TOT  H90SFU  \
# 0    611      568  ...  2728.0   2920.0   6009.0   1962.0  3839.0  3691.0
# 1   1299     1220  ...   380.0    846.0    556.0    201.0   566.0   487.0
# 2   1042      938  ...   799.0   1084.0   1628.0    748.0  1435.0  1197.0
# 3   1132     1055  ...   608.0    968.0   1092.0    339.0   960.0   667.0
# 4    516      487  ...   454.0    902.0    731.0    252.0   816.0   421.0
#
#    H90OTH  INC90MED    H90MVL  \
# 0   148.0   38150.0  116448.0
# 1    79.0   34600.0  123655.0
# 2   238.0   43799.0  152655.0
# 3   293.0   36702.0  161744.0
# 4   395.0   24976.0  139873.0
#
#                                             geometry
# 0  POLYGON ((2010981.306 627195.895, 2010985.562 ...
# 1  POLYGON ((2020599.176 646773.950, 2020593.421 ...
# 2  POLYGON ((1970302.753 633587.024, 1970303.702 ...
# 3  POLYGON ((1970159.706 646429.761, 1970530.071 ...
# 4  POLYGON ((1987195.131 635140.066, 1987161.766 ...
#
# [5 rows x 252 columns]

# %% [markdown]
# Let's check our data before moving onto trimming the census data.

# %%
gdf.info(verbose=True, null_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1656 entries, 0 to 1655
# Data columns (total 252 columns):
#  #    Column     Non-Null Count  Dtype
# ---   ------     --------------  -----
#  0    AREA       1656 non-null   float64
#  1    PERIMETER  1656 non-null   float64
#  2    CTBNA      1656 non-null   int64
#  3    P40T       1656 non-null   int64
#  4    P40WNH     1656 non-null   int64
#  5    P40BNH     1656 non-null   int64
#  6    P40ONH     1656 non-null   int64
#  7    P40HIS     1656 non-null   int64
#  8    P40TW      1656 non-null   int64
#  9    P40NATW    1656 non-null   int64
#  10   P40FBW     1656 non-null   int64
#  11   P40TOTNW   1656 non-null   int64
#  12   P40B       1656 non-null   int64
#  13   P40NBNW    1656 non-null   int64
#  14   P40MEX     1656 non-null   int64
#  15   P40CSA     1656 non-null   int64
#  16   E40H       1656 non-null   int64
#  17   E40C       1656 non-null   int64
#  18   O40WC      1656 non-null   int64
#  19   O40BC      1656 non-null   int64
#  20   O4001      1656 non-null   int64
#  21   O4002      1656 non-null   int64
#  22   O4003      1656 non-null   int64
#  23   O4004      1656 non-null   int64
#  24   O4005      1656 non-null   int64
#  25   O4006      1656 non-null   int64
#  26   O4007      1656 non-null   int64
#  27   O4008      1656 non-null   int64
#  28   O4009      1656 non-null   int64
#  29   O4010      1656 non-null   int64
#  30   O4011      1656 non-null   int64
#  31   O4012      1656 non-null   int64
#  32   O4013      1656 non-null   int64
#  33   O4005SPS   1656 non-null   int64
#  34   O4005PRS   1656 non-null   int64
#  35   H40TOT     1656 non-null   int64
#  36   H40NWT     1656 non-null   int64
#  37   H40OWN     1656 non-null   int64
#  38   H40NWO     1656 non-null   int64
#  39   H40RNT     1656 non-null   int64
#  40   H40WRN     1656 non-null   int64
#  41   H40NRN     1656 non-null   int64
#  42   H40MVL     1656 non-null   int64
#  43   H40MRN     1656 non-null   int64
#  44   P50T       1656 non-null   int64
#  45   P50WNH     1656 non-null   int64
#  46   P50BNH     1656 non-null   int64
#  47   P50ONH     1656 non-null   int64
#  48   P50HIS     1656 non-null   int64
#  49   P50TW      1656 non-null   int64
#  50   P50NATW    1656 non-null   int64
#  51   P50FBW     1656 non-null   int64
#  52   P50TOTNW   1656 non-null   int64
#  53   P50B       1656 non-null   int64
#  54   P50NBNW    1656 non-null   int64
#  55   P50SST     1656 non-null   int64
#  56   P50SSN     1656 non-null   int64
#  57   P50SSFB    1656 non-null   int64
#  58   P50MEX     1656 non-null   int64
#  59   P50CSA     1656 non-null   int64
#  60   E50H       1656 non-null   int64
#  61   E50C       1656 non-null   int64
#  62   O50WC      1656 non-null   int64
#  63   O50BC      1656 non-null   int64
#  64   O5001      1656 non-null   int64
#  65   O5001M     1656 non-null   int64
#  66   O5001F     1656 non-null   int64
#  67   O5002      1656 non-null   int64
#  68   O5002M     1656 non-null   int64
#  69   O5002F     1656 non-null   int64
#  70   O5003      1656 non-null   int64
#  71   O5003M     1656 non-null   int64
#  72   O5003F     1656 non-null   int64
#  73   O5004      1656 non-null   int64
#  74   O5004M     1656 non-null   int64
#  75   O5004F     1656 non-null   int64
#  76   O5005PRM   1656 non-null   int64
#  77   O5005PRF   1656 non-null   int64
#  78   O5005      1656 non-null   int64
#  79   O5006M     1656 non-null   int64
#  80   O5006F     1656 non-null   int64
#  81   O5006      1656 non-null   int64
#  82   O5007CLM   1656 non-null   int64
#  83   O5007CLF   1656 non-null   int64
#  84   O5007SLM   1656 non-null   int64
#  85   O5007SLF   1656 non-null   int64
#  86   O5007      1656 non-null   int64
#  87   O5008M     1656 non-null   int64
#  88   O5008F     1656 non-null   int64
#  89   O5008      1656 non-null   int64
#  90   O5009M     1656 non-null   int64
#  91   O5009F     1656 non-null   int64
#  92   O5009      1656 non-null   int64
#  93   O5010M     1656 non-null   int64
#  94   O5010F     1656 non-null   int64
#  95   O5010      1656 non-null   int64
#  96   O5011M     1656 non-null   int64
#  97   O5011F     1656 non-null   int64
#  98   O5011      1656 non-null   int64
#  99   O5012M     1656 non-null   int64
#  100  O5012F     1656 non-null   int64
#  101  O5012      1656 non-null   int64
#  102  O5013M     1656 non-null   int64
#  103  O5013F     1656 non-null   int64
#  104  O5013      1656 non-null   int64
#  105  H50TOT     1656 non-null   int64
#  106  H50NWT     1656 non-null   int64
#  107  H50OWN     1656 non-null   int64
#  108  H50NWO     1656 non-null   int64
#  109  H50RNT     1656 non-null   int64
#  110  H50NRN     1656 non-null   int64
#  111  H50MVL     1656 non-null   int64
#  112  H50MRN     1656 non-null   int64
#  113  P60T       1656 non-null   int64
#  114  P60WNH     1656 non-null   int64
#  115  P60BNH     1656 non-null   int64
#  116  P60ONH     1656 non-null   int64
#  117  P60HIS     1656 non-null   int64
#  118  P60TW      1656 non-null   int64
#  119  P60TOTNW   1656 non-null   int64
#  120  P60B       1656 non-null   int64
#  121  P60NBNW    1656 non-null   int64
#  122  P60SST     1656 non-null   int64
#  123  P60SSN     1656 non-null   int64
#  124  P60SSFB    1656 non-null   int64
#  125  P60MEX     1656 non-null   int64
#  126  E60H       1656 non-null   int64
#  127  E60C       1656 non-null   int64
#  128  O60WC      1656 non-null   int64
#  129  O60BC      1656 non-null   int64
#  130  O6001      1656 non-null   int64
#  131  O6002      1656 non-null   int64
#  132  O6003      1656 non-null   int64
#  133  O6004      1656 non-null   int64
#  134  O6005PRM   1656 non-null   int64
#  135  O6005PRF   1656 non-null   int64
#  136  O6005      1656 non-null   int64
#  137  O6006M     1656 non-null   int64
#  138  O6006F     1656 non-null   int64
#  139  O6006      1656 non-null   int64
#  140  O6007CLM   1656 non-null   int64
#  141  O6007CLF   1656 non-null   int64
#  142  O6007SLM   1656 non-null   int64
#  143  O6007SLF   1656 non-null   int64
#  144  O6007      1656 non-null   int64
#  145  O6008M     1656 non-null   int64
#  146  O6008F     1656 non-null   int64
#  147  O6008      1656 non-null   int64
#  148  O6009M     1656 non-null   int64
#  149  O6009F     1656 non-null   int64
#  150  O6009      1656 non-null   int64
#  151  O6010M     1656 non-null   int64
#  152  O6010F     1656 non-null   int64
#  153  O6010      1656 non-null   int64
#  154  O6011M     1656 non-null   int64
#  155  O6011F     1656 non-null   int64
#  156  O6011      1656 non-null   int64
#  157  O6012M     1656 non-null   int64
#  158  O6012F     1656 non-null   int64
#  159  O6012      1656 non-null   int64
#  160  O6013M     1656 non-null   int64
#  161  O6013F     1656 non-null   int64
#  162  O6013      1656 non-null   int64
#  163  H60TOT     1656 non-null   int64
#  164  H60NWT     1656 non-null   int64
#  165  H60OWN     1656 non-null   int64
#  166  H60NWO     1656 non-null   int64
#  167  H60RNT     1656 non-null   int64
#  168  H60NRN     1656 non-null   int64
#  169  H60MVL     1656 non-null   int64
#  170  H60MRN     1656 non-null   int64
#  171  P70T       1650 non-null   float64
#  172  P70WNH     1650 non-null   float64
#  173  P70BNH     1650 non-null   float64
#  174  P70ONH     1650 non-null   float64
#  175  P70HIS     1650 non-null   float64
#  176  A700004    1650 non-null   float64
#  177  A700517    1650 non-null   float64
#  178  A701864    1650 non-null   float64
#  179  A7065UP    1650 non-null   float64
#  180  A70MEDN    1650 non-null   float64
#  181  M70SINGL   1650 non-null   float64
#  182  M70MAR     1650 non-null   float64
#  183  M70OTH     1650 non-null   float64
#  184  E70C       1650 non-null   float64
#  185  E70H       1650 non-null   float64
#  186  E70OTH     1650 non-null   float64
#  187  O70WC      1648 non-null   float64
#  188  O70BC      1648 non-null   float64
#  189  R70SH65    1650 non-null   float64
#  190  R70SC65    1650 non-null   float64
#  191  R70OT65    1650 non-null   float64
#  192  H70TOT     1650 non-null   float64
#  193  H70SFU     1650 non-null   float64
#  194  H70OTH     1650 non-null   float64
#  195  INC70MED   1650 non-null   float64
#  196  H70MVL     1650 non-null   float64
#  197  H70MRN     1650 non-null   float64
#  198  P80T       1651 non-null   float64
#  199  P80WNH     1651 non-null   float64
#  200  P80BNH     1651 non-null   float64
#  201  P80ONH     1651 non-null   float64
#  202  P80HIS     1651 non-null   float64
#  203  A800004    1651 non-null   float64
#  204  A800517    1651 non-null   float64
#  205  A801864    1651 non-null   float64
#  206  A8065UP    1651 non-null   float64
#  207  A80MEDN    1651 non-null   float64
#  208  M80SINGL   1651 non-null   float64
#  209  M80MAR     1651 non-null   float64
#  210  M80OTH     1651 non-null   float64
#  211  E80C       1651 non-null   float64
#  212  E80H       1651 non-null   float64
#  213  E80OTH     1651 non-null   float64
#  214  O80WC      1651 non-null   float64
#  215  O80BC      1651 non-null   float64
#  216  R80SH75    1651 non-null   float64
#  217  R80SC75    1651 non-null   float64
#  218  R80OT75    1651 non-null   float64
#  219  H80TOT     1651 non-null   float64
#  220  H80SFU     1651 non-null   float64
#  221  H80OTH     1651 non-null   float64
#  222  INC80MED   1651 non-null   float64
#  223  H80MVL     1651 non-null   float64
#  224  H80MRN     1651 non-null   float64
#  225  P90T       1653 non-null   float64
#  226  P90WNH     1653 non-null   float64
#  227  P90BNH     1653 non-null   float64
#  228  P90ONH     1653 non-null   float64
#  229  P90HIS     1653 non-null   float64
#  230  A900004    1653 non-null   float64
#  231  A900517    1653 non-null   float64
#  232  A901864    1653 non-null   float64
#  233  A9065UP    1653 non-null   float64
#  234  A90MEDN    1653 non-null   float64
#  235  M90SINGL   1653 non-null   float64
#  236  M90MAR     1653 non-null   float64
#  237  M90OTH     1653 non-null   float64
#  238  E90C       1653 non-null   float64
#  239  E90H       1653 non-null   float64
#  240  E90OTH     1653 non-null   float64
#  241  O90WC      1653 non-null   float64
#  242  O90BC      1653 non-null   float64
#  243  R90SH85    1653 non-null   float64
#  244  R90SC85    1653 non-null   float64
#  245  R90OT85    1653 non-null   float64
#  246  H90TOT     1653 non-null   float64
#  247  H90SFU     1653 non-null   float64
#  248  H90OTH     1653 non-null   float64
#  249  INC90MED   1653 non-null   float64
#  250  H90MVL     1653 non-null   float64
#  251  geometry   1656 non-null   geometry
# dtypes: float64(82), geometry(1), int64(169)
# memory usage: 3.2 MB
# /tmp/ipykernel_727/1396010356.py:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   gdf.info(verbose=True, null_counts=True)

# %%
gb47.info(verbose=True, null_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1056 entries, 0 to 1055
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 1056 non-null   object
#  1   address              1056 non-null   object
#  2   image_url            1056 non-null   object
#  3   image_id             1056 non-null   object
#  4   capture_uuid         1056 non-null   object
#  5   dc_url               1056 non-null   object
#  6   page                 1056 non-null   int64
#  7   year                 1056 non-null   int64
#  8   city                 1056 non-null   object
#  9   state                1056 non-null   object
#  10  category             1056 non-null   object
#  11  image_region         1056 non-null   object
#  12  geocoded_address     1056 non-null   object
#  13  geocoded_confidence  1056 non-null   float64
#  14  geometry             1056 non-null   geometry
# dtypes: float64(1), geometry(1), int64(2), object(11)
# memory usage: 123.9+ KB
# /tmp/ipykernel_727/3110117373.py:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   gb47.info(verbose=True, null_counts=True)

# %%
gb1956.info(verbose=True, null_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1505 entries, 0 to 1504
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      1505 non-null   object
#  1   address   1505 non-null   object
#  2   city      1505 non-null   object
#  3   state     1505 non-null   object
#  4   zip       1505 non-null   object
#  5   category  1505 non-null   object
#  6   year      1505 non-null   object
#  7   LAT       1505 non-null   object
#  8   LONG      1505 non-null   object
#  9   geometry  1505 non-null   geometry
# dtypes: geometry(1), object(9)
# memory usage: 117.7+ KB
# /tmp/ipykernel_727/1737694910.py:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   gb1956.info(verbose=True, null_counts=True)

# %%
import os

gdf.AREA.head()
# Out:
# 0    5.110526e+08
# 1    4.139640e+08
# 2    9.627060e+08
# 3    2.129940e+08
# 4    5.892047e+07
# Name: AREA, dtype: float64

# %%
gdf.PERIMETER.head()
# Out:
# 0     97788.60030
# 1    112335.98215
# 2    143092.75454
# 3     60542.54667
# 4     38184.45935
# Name: PERIMETER, dtype: float64

# %%
gdf.plot()
plt.show()

# %%
gb47.plot()
plt.show()

# %%
gb1956.plot()
plt.show()

# %%
# reproject to web mercator
gb56_web_mercator = gb1956.to_crs(epsg=3857)

# map it
fig, ax = plt.subplots(figsize=(15,5))

gb56_web_mercator.plot(ax=ax, 
                      marker='o',
                      markersize=15,
                      color='blue')

ax.axis('off')

ax.set_title('Greenbook Locations, 1956')

ctx.add_basemap(ax)

# %% [markdown]
# #yay! our data is working well.

# %% [markdown]
# Let's do some initial descriptive stats for our data.

# %%
gb1956.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1505 entries, 0 to 1504
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      1505 non-null   object
#  1   address   1505 non-null   object
#  2   city      1505 non-null   object
#  3   state     1505 non-null   object
#  4   zip       1505 non-null   object
#  5   category  1505 non-null   object
#  6   year      1505 non-null   object
#  7   LAT       1505 non-null   object
#  8   LONG      1505 non-null   object
#  9   geometry  1505 non-null   geometry
# dtypes: geometry(1), object(9)
# memory usage: 117.7+ KB

# %%
gb47.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1056 entries, 0 to 1055
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 1056 non-null   object
#  1   address              1056 non-null   object
#  2   image_url            1056 non-null   object
#  3   image_id             1056 non-null   object
#  4   capture_uuid         1056 non-null   object
#  5   dc_url               1056 non-null   object
#  6   page                 1056 non-null   int64
#  7   year                 1056 non-null   int64
#  8   city                 1056 non-null   object
#  9   state                1056 non-null   object
#  10  category             1056 non-null   object
#  11  image_region         1056 non-null   object
#  12  geocoded_address     1056 non-null   object
#  13  geocoded_confidence  1056 non-null   float64
#  14  geometry             1056 non-null   geometry
# dtypes: float64(1), geometry(1), int64(2), object(11)
# memory usage: 123.9+ KB

# %%
gb47['city'].value_counts()
# Out:
# LOS ANGELES             101
# ST. JOSEPH               57
# COLORADO SPRINGS V       51
# DISTRICT OF COLUMBIA     47
# LITTLE ROCK              47
#                        ...
# ORLANDO                   1
# ST AUGUSTINE              1
# MORGAN CITY               1
# MONROE                    1
# GARY                      1
# Name: city, Length: 167, dtype: int64

# %%
gb1956['city'].value_counts()
# Out:
#  New York                                         34
#  Philadelphia                                     32
#  Washington                                       31
#  Columbus                                         27
#  Atlantic City                                    27
#                                                   ..
#  Camden                                            1
#  Fordyce                                           1
#  Elizabeth                                         1
#  246 miles east of Forrest City [near Madison]     1
#  Quebec                                            1
# Name: city, Length: 438, dtype: int64

# %%
#save as new variable
# city_count47 = gb47['city'].value_counts()

# city_count47.head(10).plot.bar(x = 'city', y = 'count', title = 'Top 10 Cities in the Green Book, 1947')

# %%
#save as new variable
# city_count56 = gb1956['city'].value_counts()

# city_count56.head(10).plot.bar(x = 'city', y = 'count', title = 'Top 10 Cities in the Green Book, 1956')

# %% [markdown]
# # 2. Trim census tract data to 1940, 1950, and 1960.

# %%
columns_to_drop70 = ['P70T','P70WNH', 'P70BNH', 'P70ONH','P70HIS', 'A700004', 'A700517', 'A701864', 'A7065UP', 'A70MEDN', 'M70SINGL', 'M70MAR', 'M70OTH', 'E70C', 'E70H', 'E70OTH', 'O70WC', 'O70BC', 'R70SH65', 'R70SC65', 'R70OT65', 'H70TOT', 'H70SFU', 'H70OTH', 'INC70MED', 'H70MVL', 'H70MRN']
columns_to_drop80 = ['P80T', 'P80WNH', 'P80BNH', 'P80ONH', 'P80HIS', 'A800004', 'A800517', 'A801864', 'A8065UP', 'A80MEDN', 'M80SINGL', 'M80MAR', 'M80OTH', 'E80C', 'E80H', 'E80OTH', 'O80WC', 'O80BC', 'R80SH75', 'R80SC75', 'R80OT75', 'H80TOT', 'H80SFU', 'H80OTH', 'INC80MED', 'H80MVL', 'H80MRN']
columns_to_drop90 = ['P90T', 'P90WNH', 'P90BNH', 'P90ONH', 'P90HIS', 'A900004', 'A900517', 'A901864', 'A9065UP', 'A90MEDN', 'M90SINGL', 'M90MAR', 'M90OTH', 'E90C', 'E90H', 'E90OTH', 'O90WC', 'O90BC', 'R90SH85', 'R90SC85', 'R90OT85', 'H90TOT', 'H90SFU', 'H90OTH', 'INC90MED', 'H90MVL']

# %%
drops = [columns_to_drop70, columns_to_drop80, columns_to_drop90]

# %%
# loop through routes = for loop; all indented below is part of for loop
for drop in drops:

    gdf = gdf.drop(drop, axis=1)

gdf.head()
# Out:
#            AREA     PERIMETER   CTBNA  P40T  P40WNH  P40BNH  P40ONH  P40HIS  \
# 0  5.110526e+08   97788.60030  900100   615     605       1       3       6
# 1  4.139640e+08  112335.98215  900200  1312    1287       2      11      12
# 2  9.627060e+08  143092.75454  901202  1063    1038       1      20       4
# 3  2.129940e+08   60542.54667  900900  1150    1122       3      14      10
# 4  5.892047e+07   38184.45935  900300   522     511       2       5       5
#
#    P40TW  P40NATW  ...  O6013  H60TOT  H60NWT  H60OWN  H60NWO  H60RNT  H60NRN  \
# 0    611      568  ...     13     634      39     136      24      57      15
# 1   1299     1220  ...     58     643       4     284       1     192       3
# 2   1042      938  ...     36    1402      14     533       7     313       7
# 3   1132     1055  ...      4     317      32     122      21      69      11
# 4    516      487  ...      5     362      21     149      12     129       9
#
#    H60MVL  H60MRN                                           geometry
# 0       0       0  POLYGON ((2010981.306 627195.895, 2010985.562 ...
# 1       0       0  POLYGON ((2020599.176 646773.950, 2020593.421 ...
# 2   11100       0  POLYGON ((1970302.753 633587.024, 1970303.702 ...
# 3    5384       0  POLYGON ((1970159.706 646429.761, 1970530.071 ...
# 4   11200       0  POLYGON ((1987195.131 635140.066, 1987161.766 ...
#
# [5 rows x 172 columns]

# %%
gdf.columns.to_list()

# %% [markdown]
# # 3. Calculate % of education levels and collar work for 1940, 1950, and 1960.

# %% [markdown]
# Calculating and adding these columns will give us a better sense of the overall economic picture.  Where were concentrations of workers that completed high school? College? Blue collar? White collar?

# %%
# indicators = ['E40H','E50H', 'E60H', 'E40C', 'E50C', 'E60C', 'O40WC', 'O50WC', 'O60WC', 'O40BC', 'O50BC', 'O60BC']
# ed_indicators = ['E40H','E50H', 'E60H', 'E40C', 'E50C', 'E60C']
# wage_indicators = ['O40WC', 'O50WC', 'O60WC', 'O40BC', 'O50BC', 'O60BC']

# %%
# loop through routes = for loop; all indented below is part of for loop
# for ed_indicator in ed_indicators:

    # gdf['Pct_+ str(ed_indicator)'] = ''
   # gdf['Pct_+ str(ed_indicator)'] = gdf['ed_indicator']/gdf[''] *100

# gdf.head()

# %%
gdf['Pct_HS_40'] = ''
gdf['Pct_HS_40'] = gdf['E40H']/gdf['P40T'] *100

gdf['Pct_College_40'] = ''
gdf['Pct_College_40'] = gdf['E40C']/gdf['P40T'] *100

gdf['Pct_WC_40'] = ''
gdf['Pct_WC_40'] = gdf['O40WC']/gdf['O4001'] *100

gdf['Pct_BC_40'] = ''
gdf['Pct_BC_40'] = gdf['O40BC']/gdf['O4001'] *100

# %%
gdf.head()
# Out:
#            AREA     PERIMETER   CTBNA  P40T  P40WNH  P40BNH  P40ONH  P40HIS  \
# 0  5.110526e+08   97788.60030  900100   615     605       1       3       6
# 1  4.139640e+08  112335.98215  900200  1312    1287       2      11      12
# 2  9.627060e+08  143092.75454  901202  1063    1038       1      20       4
# 3  2.129940e+08   60542.54667  900900  1150    1122       3      14      10
# 4  5.892047e+07   38184.45935  900300   522     511       2       5       5
#
#    P40TW  P40NATW  ...  H60NWO  H60RNT  H60NRN  H60MVL  H60MRN  \
# 0    611      568  ...      24      57      15       0       0
# 1   1299     1220  ...       1     192       3       0       0
# 2   1042      938  ...       7     313       7   11100       0
# 3   1132     1055  ...      21      69      11    5384       0
# 4    516      487  ...      12     129       9   11200       0
#
#                                             geometry  Pct_HS_40  \
# 0  POLYGON ((2010981.306 627195.895, 2010985.562 ...   8.943089
# 1  POLYGON ((2020599.176 646773.950, 2020593.421 ...  10.899390
# 2  POLYGON ((1970302.753 633587.024, 1970303.702 ...   9.407338
# 3  POLYGON ((1970159.706 646429.761, 1970530.071 ...  11.304348
# 4  POLYGON ((1987195.131 635140.066, 1987161.766 ...  11.685824
#
#    Pct_College_40   Pct_WC_40  Pct_BC_40
# 0        1.138211  102.173913  91.304348
# 1        2.896341   87.248322  68.120805
# 2        1.505174   80.811808  75.645756
# 3        3.217391   84.859155  65.845070
# 4        3.639847   83.582090  62.686567
#
# [5 rows x 176 columns]

# %%
gdf['Pct_HS_50'] = ''
gdf['Pct_HS_50'] = gdf['E50H']/gdf['P50T'] *100

gdf['Pct_College_50'] = ''
gdf['Pct_College_50'] = gdf['E50C']/gdf['P50T'] *100

gdf['Pct_WC_50'] = ''
gdf['Pct_WC_50'] = gdf['O50WC']/gdf['O5001'] *100

gdf['Pct_BC_50'] = ''
gdf['Pct_BC_50'] = gdf['O50BC']/gdf['O5001'] *100

# %%
gdf.head()
# Out:
#            AREA     PERIMETER   CTBNA  P40T  P40WNH  P40BNH  P40ONH  P40HIS  \
# 0  5.110526e+08   97788.60030  900100   615     605       1       3       6
# 1  4.139640e+08  112335.98215  900200  1312    1287       2      11      12
# 2  9.627060e+08  143092.75454  901202  1063    1038       1      20       4
# 3  2.129940e+08   60542.54667  900900  1150    1122       3      14      10
# 4  5.892047e+07   38184.45935  900300   522     511       2       5       5
#
#    P40TW  P40NATW  ...  H60MRN  \
# 0    611      568  ...       0
# 1   1299     1220  ...       0
# 2   1042      938  ...       0
# 3   1132     1055  ...       0
# 4    516      487  ...       0
#
#                                             geometry  Pct_HS_40  \
# 0  POLYGON ((2010981.306 627195.895, 2010985.562 ...   8.943089
# 1  POLYGON ((2020599.176 646773.950, 2020593.421 ...  10.899390
# 2  POLYGON ((1970302.753 633587.024, 1970303.702 ...   9.407338
# 3  POLYGON ((1970159.706 646429.761, 1970530.071 ...  11.304348
# 4  POLYGON ((1987195.131 635140.066, 1987161.766 ...  11.685824
#
#    Pct_College_40   Pct_WC_40  Pct_BC_40  Pct_HS_50  Pct_College_50  \
# 0        1.138211  102.173913  91.304348  14.436249        2.950474
# 1        2.896341   87.248322  68.120805  14.457831        3.295535
# 2        1.505174   80.811808  75.645756  13.226300        3.516820
# 3        3.217391   84.859155  65.845070  14.509954        3.292496
# 4        3.639847   83.582090  62.686567  14.411529        3.362690
#
#     Pct_WC_50   Pct_BC_50
# 0  230.769231  125.641026
# 1  156.186613   77.484787
# 2  146.956522   76.956522
# 3  144.791667   71.458333
# 4  143.404255   69.361702
#
# [5 rows x 180 columns]

# %%
gdf['Pct_HS_60'] = ''
gdf['Pct_HS_60'] = gdf['E60H']/gdf['P60T'] *100

gdf['Pct_College_60'] = ''
gdf['Pct_College_60'] = gdf['E60C']/gdf['P60T'] *100

gdf['Pct_WC_60'] = ''
gdf['Pct_WC_60'] = gdf['O60WC']/gdf['O6001'] *100

gdf['Pct_BC_60'] = ''
gdf['Pct_BC_60'] = gdf['O60BC']/gdf['O6001'] *100

# %%
gdf.head()
# Out:
#            AREA     PERIMETER   CTBNA  P40T  P40WNH  P40BNH  P40ONH  P40HIS  \
# 0  5.110526e+08   97788.60030  900100   615     605       1       3       6
# 1  4.139640e+08  112335.98215  900200  1312    1287       2      11      12
# 2  9.627060e+08  143092.75454  901202  1063    1038       1      20       4
# 3  2.129940e+08   60542.54667  900900  1150    1122       3      14      10
# 4  5.892047e+07   38184.45935  900300   522     511       2       5       5
#
#    P40TW  P40NATW  ...   Pct_WC_40  Pct_BC_40  Pct_HS_50  Pct_College_50  \
# 0    611      568  ...  102.173913  91.304348  14.436249        2.950474
# 1   1299     1220  ...   87.248322  68.120805  14.457831        3.295535
# 2   1042      938  ...   80.811808  75.645756  13.226300        3.516820
# 3   1132     1055  ...   84.859155  65.845070  14.509954        3.292496
# 4    516      487  ...   83.582090  62.686567  14.411529        3.362690
#
#     Pct_WC_50   Pct_BC_50  Pct_HS_60  Pct_College_60   Pct_WC_60  Pct_BC_60
# 0  230.769231  125.641026  15.745394        2.847571   87.628866  91.752577
# 1  156.186613   77.484787  19.260204        2.104592  146.179402  75.415282
# 2  146.956522   76.956522  17.096432        2.260685  145.610687  70.229008
# 3  144.791667   71.458333  15.060241        1.506024   80.487805  71.341463
# 4  143.404255   69.361702  17.283951        1.010101   99.056604  58.018868
#
# [5 rows x 184 columns]

# %%
gdf.plot(figsize=(12,10),
                 column='Pct_HS_40',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <AxesSubplot:>

# %%
# create the 1x2 subplots - High School Education
fig, axs = plt.subplots(1, 2, figsize=(15, 12))

# name each subplot
ax1, ax2 = axs

# 1940 map on the left HS
gdf.plot(column='Pct_HS_40', 
            cmap='RdYlGn_r', 
            scheme='NaturalBreaks',
            edgecolor='white', 
            linewidth=0., 
            alpha=0.75, 
            ax=ax1, # this assigns the map to the subplot,
            legend=True
           )

ax1.axis("off")
ax1.set_title("% Completed High School in Los Angeles County, 1940", fontsize=12, weight='bold')
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# 1960 on the right HS
gdf.plot(column='Pct_HS_60', 
            cmap='RdYlGn_r', 
            scheme='NaturalBreaks',
            edgecolor='white', 
            linewidth=0., 
            alpha=0.75, 
            ax=ax2, # this assigns the map to the subplot,
            legend=True
           )

ax2.axis("off")
ax2.set_title("% Completed High School in Los Angeles County, 1960", fontsize=12, weight='bold')
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %%
# create the 1x2 subplots - college
fig, axs = plt.subplots(1, 2, figsize=(15, 12))

# name each subplot
ax1, ax2 = axs

# 1940 map on the left
gdf.plot(column='Pct_College_40', 
            cmap='RdYlGn_r', 
            scheme='NaturalBreaks',
            edgecolor='white', 
            linewidth=0., 
            alpha=0.75, 
            ax=ax1, # this assigns the map to the subplot,
            legend=True
           )

ax1.axis("off")
ax1.set_title("% Completed College in Los Angeles County, 1940", fontsize=12, weight='bold')

# 1960 on the right
gdf.plot(column='Pct_College_60', 
            cmap='RdYlGn_r', 
            scheme='NaturalBreaks',
            edgecolor='white', 
            linewidth=0., 
            alpha=0.75, 
            ax=ax2, # this assigns the map to the subplot,
            legend=True
           )

ax2.axis("off")
ax2.set_title("% Completed College in Los Angeles County, 1960", fontsize=12, weight='bold')
# Out:
# Text(0.5, 1.0, '% Completed College in Los Angeles County, 1960')

# %%
# create the 1x2 subplots - white collar work
fig, axs = plt.subplots(1, 2, figsize=(15, 12))

# name each subplot
ax1, ax2 = axs

# 1940 map on the left
gdf.plot(column='Pct_WC_40', 
            cmap='RdYlGn_r', 
            scheme='user_defined',
            classification_kwds={'bins':[20,40,60,80,100]},
            edgecolor='white', 
            linewidth=0., 
            alpha=0.75, 
            ax=ax1, # this assigns the map to the subplot,
            legend=True
           )

ax1.axis("off")
ax1.set_title("% White Collar Workers in Los Angeles County, 1940", fontsize=12, weight='bold')

# 1960 on the right
gdf.plot(column='Pct_WC_60', 
            cmap='RdYlGn_r', 
            scheme='NaturalBreaks',
            edgecolor='white', 
            linewidth=0., 
            alpha=0.75, 
            ax=ax2, # this assigns the map to the subplot,
            legend=True
           )

ax2.axis("off")
ax2.set_title("% White Collar Workers in Los Angeles County, 1960", fontsize=12, weight='bold')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_727/1004248097.py in <module>
#      21
#      22 # 1960 on the right
# ---> 23 gdf.plot(column='Pct_WC_60',
#      24             cmap='RdYlGn_r',
#      25             scheme='NaturalBreaks',
#
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py in __call__(self, *args, **kwargs)
#     923             kind = kwargs.pop("kind", "geo")
#     924             if kind == "geo":
# --> 925                 return plot_dataframe(data, *args, **kwargs)
#     926             if kind in self._pandas_kinds:
#     927                 # Access pandas plots
#
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     750             classification_kwds["k"] = k
#     751
# --> 752         binning = _mapclassify_choro(values[~nan_idx], scheme, **classification_kwds)
#     753         # set categorical to True for creating the legend
#     754         categorical = True
#
# /opt/conda/lib/python3.9/site-packages/geopandas/plotting.py in _mapclassify_choro(values, scheme, **classification_kwds)
#    1026             del classification_kwds["k"]
#    1027     try:
# -> 1028         binning = scheme_class(np.asarray(values), **classification_kwds)
#    1029     except TypeError:
#    1030         raise TypeError("Invalid keyword argument for %r " % scheme)
#
# /opt/conda/lib/python3.9/site-packages/mapclassify/classifiers.py in __init__(self, y, k, initial)
#    1704         self.k = k
#    1705         self.init = initial
# -> 1706         MapClassifier.__init__(self, y)
#    1707         self.name = "NaturalBreaks"
#    1708
#
# /opt/conda/lib/python3.9/site-packages/mapclassify/classifiers.py in __init__(self, y)
#     615         self.fmt = FMT
#     616         self.y = y
# --> 617         self._classify()
#     618         self._summary()
#     619
#
# /opt/conda/lib/python3.9/site-packages/mapclassify/classifiers.py in _classify(self)
#     634
#     635     def _classify(self):
# --> 636         self._set_bins()
#     637         self.yb, self.counts = bin1d(self.y, self.bins)
#     638
#
# /opt/conda/lib/python3.9/site-packages/mapclassify/classifiers.py in _set_bins(self)
#    1725             self.k = k
#    1726         else:
# -> 1727             res0 = natural_breaks(x, k, init=self.init)
#    1728             fit = res0[2]
#    1729             self.bins = np.array(res0[-1])
#
# /opt/conda/lib/python3.9/site-packages/mapclassify/classifiers.py in natural_breaks(values, k, init)
#     500         Warn("Warning: setting k to %d" % uvk, UserWarning)
#     501         k = uvk
# --> 502     kres = _kmeans(values, k, n_init=init)
#     503     sids = kres[-1]  # centroids
#     504     fit = kres[-2]
#
# /opt/conda/lib/python3.9/site-packages/mapclassify/classifiers.py in _kmeans(y, k, n_init)
#     451     y = y * 1.0  # KMEANS needs float or double dtype
#     452     y.shape = (-1, 1)
# --> 453     result = KMEANS(n_clusters=k, init="k-means++", n_init=n_init).fit(y)
#     454     class_ids = result.labels_
#     455     centroids = result.cluster_centers_
#
# /opt/conda/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#     977             Fitted estimator.
#     978         """
# --> 979         X = self._validate_data(X, accept_sparse='csr',
#     980                                 dtype=[np.float64, np.float32],
#     981                                 order='C', copy=self.copy_x,
#
# /opt/conda/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     718
#     719         if force_all_finite:
# --> 720             _assert_all_finite(array,
#     721                                allow_nan=force_all_finite == 'allow-nan')
#     722
#
# /opt/conda/lib/python3.9/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     101                 not allow_nan and not np.isfinite(X).all()):
#     102             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# --> 103             raise ValueError(
#     104                     msg_err.format
#     105                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
# create the 1x2 subplots - blue collar
fig, axs = plt.subplots(1, 2, figsize=(15, 12))

# name each subplot
ax1, ax2 = axs

# 1940 map on the left
gdf.plot(column='Pct_BC_40', 
            cmap='RdYlGn_r', 
            scheme='user_defined',
            classification_kwds={'bins':[20,40,60,80,100]},
            edgecolor='white', 
            linewidth=0., 
            alpha=0.75, 
            ax=ax1, # this assigns the map to the subplot,
            legend=True
           )

ax1.axis("off")
ax1.set_title("% Blue Collar Workers in Los Angeles County, 1940", fontsize=12, weight='bold')

# 1960 on the right
gdf.plot(column='Pct_BC_60', 
            cmap='RdYlGn_r', 
            scheme='user_defined',
            classification_kwds={'bins':[20,40,60,80,100]},
            edgecolor='white', 
            linewidth=0., 
            alpha=0.75, 
            ax=ax2, # this assigns the map to the subplot,
            legend=True
           )

ax2.axis("off")
ax2.set_title("% Blue Collar Workers in Los Angeles County, 1960", fontsize=12, weight='bold')
# Out:
# /opt/conda/lib/python3.9/site-packages/mapclassify/classifiers.py:860: RuntimeWarning: invalid value encountered in subtract
#   css = yc - yc.mean()
# /opt/conda/lib/python3.9/site-packages/mapclassify/classifiers.py:882: RuntimeWarning: invalid value encountered in subtract
#   ycd = np.abs(yc - yc_med)
# Text(0.5, 1.0, '% Blue Collar Workers in Los Angeles County, 1960')

# %% [markdown]
# Based on our previous exploration, ***which Census tracts have the highest Black population?*** In 1940, this will give us a sense of where Black people could live. In 1950 and 1960, this will give us a sense of both where Black people lived after the outlaw of racially restrictive covenants. *What correlations are there with our Green Book data locations?*

# %%
#Let's start with 1940.
gdf_sorted = gdf.sort_values(by='Pct_black_40',ascending = False)

# %%
gdf_sorted[['CTBNA','Pct_black_40']].head(10)

# %%
gdf_sorted.head(10).plot.bar(x='CTBNA',
                            y='Pct_black_40',
                            title='Top 10 Census Tracts with Highest % Black Population in Los Angeles County, 1940')

# %%
#1960
gdf_sorted2 = gdf.sort_values(by='Pct_black_60',ascending = False)

# %%
gdf_sorted2[['CTBNA','Pct_black_60']].head(10)

# %%
gdf_sorted.head(10).plot.bar(x='CTBNA',
                            y='Pct_black_60',
                            title='Top 10 Census Tracts with Highest % Black Population in Los Angeles County, 1960')

# %%
#change CTBNA label

# %% [markdown]
# # 4. Trim or bound GB1947 and GB1956 to Los Angeles locations.

# %%
#create new variable
la47 = gb47.query("city == 'LOS ANGELES'")

#add dataframe
la47 = la47.reset_index()
la47

# %%
#create new variable
la56 = gb1956.query("city == ' Los Angeles'")

#add dataframe
la56 = la56.reset_index()
la56

# %%
la47.info()

# %%
la56.info()

# %%
category_countla47 = la47['category'].value_counts()
category_countla47.plot.bar(x = 'category', y = 'count', title = 'Green Book Location Types in Los Angeles, 1947')

# %%
# add labels by providing a dict
fig = px.bar(
        la47,
        x='category',
        title='Green Book Location Types in Los Angeles, 1947',
        labels={
            'category':'Location Type',
            'count':'Number of Locations'
        } # change labels based on dictionary
)

# get rid of white lines inside the bars
fig.update_traces(marker_line_width=0)

# show the figure
fig.show()

# %%
category_countla56 = la56['category'].value_counts()
category_countla56.plot.bar(x = 'category', y = 'count', title = 'Green Book Location Types in Los Angeles, 1956')

# %%
# add labels by providing a dict
fig = px.bar(
        la56,
        x='category',
        title='Green Book Location Types in Los Angeles, 1956',
        labels={
            'category':'Location Type',
            'count':'Number of Locations'
        } # change labels based on dictionary
)

# get rid of white lines inside the bars
fig.update_traces(marker_line_width=0)

# show the figure
fig.show()

# %%
la47.query("name == 'Waffle Shop'")

# %%
la47 = la47.drop(labels=33,axis=0)
la47.query("name == 'Waffle Shop'")

# %%
la47.query("name == 'Billy Bergs'")

# %%
la47 = la47.drop(labels=76,axis=0)
la47.query("name == 'Billy Bergs'")

# %%
la47.query("address == '3903 S. Central Avenue'")

# %%
la47 = la47.drop(labels=81,axis=0)
la47.query("address == '3903 S. Central Avenue'")

# %%
la47.query("address == '4500 S. Avalon Avenue'")

# %%
la47 = la47.drop(labels=84,axis=0)
la47.query("address == '4500 S. Avalon Avenue'")

# %%
# reproject to web mercator
la47_web_mercator = la47.to_crs(epsg=3857)

# map it
fig, ax = plt.subplots(figsize=(20, 20))

la47_web_mercator.plot(ax=ax, 
                      marker='o',
                      markersize=50,
                      color='red')

#no axis
ax.axis('off')

#Add a Title
ax.set_title('Greenbook Locations, 1947')

#add a basemap
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron)

# %%
ax = la47_web_mercator.plot(figsize=(20,20),
                              column='category',
                              legend=True,
                             markersize=10)

ax.axis('off')

#Add a Title
ax.set_title('Greenbook Locations in Los Angeles, 1947')

ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %%
# reproject to web mercator
la56_web_mercator = la56.to_crs(epsg=3857)

# map it
fig, ax = plt.subplots(figsize=(20, 20))

la56_web_mercator.plot(ax=ax, 
                      marker='3',
                      markersize=50,
                      color='blue')

ax.axis('off')

ax.set_title('Greenbook Locations in Los Angeles, 1956')

ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron)

# %%
ax = la56_web_mercator.plot(figsize=(20,20),
                              column='category',
                              legend=True,
                             markersize=10)

ax.axis('off')

#Add a Title
ax.set_title('Greenbook Locations in Los Angeles, 1956')

ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %% [markdown]
# At a glance, it appears there was a significant reduction in the commercial corridor in Historic South Central. This is consistent with the observation that there was a reduction in many commercial locations from 1947 to 1956.

# %% [markdown]
# *How did race change in the surrounding area of the Greenbook locations from 1940 to 1960?*

# %% [markdown]
# # 5. Create multi-layered subplots for GB1947 and 1940 census.

# %%
#Create an x coordinate column
gb47['long'] = gb47['geometry'].apply(lambda p: p.x)

#Create an y coordinate column
gb47['lat'] = gb47['geometry'].apply(lambda p: p.y)

# %%
gb47.head()

# %%
#Create an x coordinate column
la47['lon'] = la47['geometry'].apply(lambda p: p.x)

#Create an y coordinate column
la47['lat'] = la47['geometry'].apply(lambda p: p.y)
la47.head()

# %%
# convert lat/lon's to floats
gb47['lat'] = gb47['lat'].astype(float)
gb47['long'] = gb47['long'].astype(float)
gb47.info()

# %%
# identify the outlier
gb47[gb47.lat == 0]

# %%
# convert lat/lon's to floats
la56['LAT'] = la56['LAT'].astype(float)
la56['LONG'] = la56['LONG'].astype(float)
la56.info()

# %%
# identify the outlier
la56[la56.LAT == 0]

# %%
#no outliers...let's map this baby.
# in order to drop the outlier, we can "keep" the other rows using the "not equal" notation (!=)
# gb47 = df_mini[df_mini.lon != 0]
#df_mini to be equal to itself with a query --> i want to keep records wher elong is not = 0

# %%
# check the plot again
fig = px.scatter(la47,
           x='lon',
           y='lat'
)

fig.show()

# %%
# before you run this cell, what do you think it will produce?
fig = px.scatter_mapbox(la47, 
                        lat="lat", 
                        lon="lon", 
                        color="category",
                        labels={'category':'Location Types'}
                       )

fig.update_layout(mapbox_style="carto-darkmatter")

fig.show()

# %%
# check the plot again
fig = px.scatter(la56,
           x='LONG',
           y='LAT'
)

fig.show()

# %%
# before you run this cell, what do you think it will produce?
fig = px.scatter_mapbox(la56, 
                        lat="LAT", 
                        lon="LONG", 
                        color="category",
                        labels={'category':'Location Types'}
                       )

fig.update_layout(mapbox_style="carto-darkmatter")

fig.show()

# %%
gdf.info(verbose=True, null_counts=True)

# %%
# subset the data below (don't forget to add .copy at the end)
gdf_mini = gdf[['AREA','PERIMETER','CTBNA','geometry','Pct_black_40','Pct_white_40','Pct_black_50','Pct_white_50','Pct_black_60','Pct_white_60',]].copy()
#need to subset by putting inside brackets

# %%
# set up the plot canvas with plt.subplots; single subplot
fig, ax = plt.subplots(figsize=(20, 20))

# block groups
gdf.plot(ax=ax,
        column='Pct_black_40',
        legend=True,
        alpha=0.8,
        cmap='RdYlGn_r',
        scheme='quantiles')

# GB 1847
la47_web_mercator.plot(ax=ax, # this also puts it in the same ax plot
            color='red',
            markersize=10,
            alpha=0.2)

# no axis
ax.axis('off')

# add a basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %%
#map it
fig, ax = plt.subplots(figsize=(12,12))

# 1940 map
gdf.plot(column='Pct_white_40', 
            cmap='RdYlGn_r', 
            scheme='user_defined',
            classification_kwds={'bins':[20,40,60,80,100]},
            edgecolor='white', 
            linewidth=0., 
            alpha=0.75, 
            ax=ax1, # this assigns the map to the subplot,
            legend=True
           )

la47_web_mercator.plot(ax=ax,
         lw=0.5,
         alpha=0.4,
        column='category',
        legend=True,
         markersize=10)

ax.set_title('Greenbook Locations in Los Angeles and % Black, 1947',fontsize=16, weight='bold')

# no axis
ax.axis('off')

# add a basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %%
# reproject to web mercator
gdf_web_mercator = gdf.to_crs(epsg=3857)

# map it
fig, ax = plt.subplots(figsize=(20, 20))


#race
gdf.plot(ax=ax,
                 column='Pct_black_40',
                 legend=True, 
                 scheme='NaturalBreaks')


#Greenbook locations
ax = la47_web_mercator.plot(ax=ax,
                              column='category',
                              legend=True,
                             markersize=10)

#no axis
ax.axis('off')

#Add a Title
ax.set_title('Greenbook Locations, 1947')

#add a basemap
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron)

# %%
ax = la47_web_mercator.plot(figsize=(20,20),
                              column='category',
                              legend=True,
                             markersize=10)

ax.axis('off')

#Add a Title
ax.set_title('Greenbook Locations in Los Angeles, 1947')

ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %% [markdown]
# Let's try a Kepler map.

# %%
from keplergl import KeplerGl

map = KeplerGl(height=600,width=800)
map

# %%
map.add_data(data=la47,name='1947') #add_data = give it arguments
#defined map above

# %%
map.add_data(data=gdf,name='census') #add_data = give it arguments
#defined map above

# %%
map.save_to_html(file_name='la_arrests.html',read_only=True)

# %%
NEXT
SUBPLOT CODE

DEF
def race_map(race='H'): #give a default value
    
    fig = px.scatter_mapbox(
                            df_mini[df_mini.descent_cd==race], #subset of what we want to map from df_mini to only include when race = race (variable)
                            lat="lat", 
                            lon="lon", 
                            color="descent_cd",
                            labels={'descent_cd':'Race'}
                           )

    fig.update_layout(mapbox_style="carto-darkmatter")

    fig.show()

LOOP/Function

# %% [markdown]
# # 6. Create a function and loop through all racial categories.

# %%
#create a list
races = [pct_black_40, pct_white_40, pct_black_50, pct_white_50, pct_black_60, pct_white_60]

# %%
# loop through routes = for loop; all indented below is part of for loop
for race in races:

    # api url for metro stops = most important place to put variable
    metro_url = 'https://api.metro.net/agencies/lametro/routes/' + str(route) + '/stops/'

    # call the api and bring the data in
    with urllib.request.urlopen(metro_url) as url:
        data = json.loads(url.read().decode())

    # convert the data to a dataframe
    df = pd.json_normalize(data, 'items')
    df
    
    # convert df to gdf
    gdf = gpd.GeoDataFrame(df, 
                           crs='epsg:4326',
                           geometry=gpd.points_from_xy(df.longitude, df.latitude))
    
    # reproject to web mercator
    gdf_web_mercator = gdf.to_crs(epsg=3857)

    # map it
    fig, ax = plt.subplots(figsize=(15,15))

    gdf_web_mercator.plot(ax=ax, 
                          marker='X',
                          markersize=50,
                          color='red')

    ax.axis('off')

    ax.set_title('Metro Bus Route '+str(route))

    ctx.add_basemap(ax, source=ctx.providers.Stamen.Toner, zoom=13)

# %% [markdown]
# # 7. Repeat for GB1956 and 1960 census.

# %% [markdown]
# Let's explore the data!

# %% [markdown]
# How many different categories are there in 1956?

# %%
gb56['category'].plot.hist(bins=50)
